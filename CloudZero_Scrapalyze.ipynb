# %% [markdown]
# # Scrapalyze:  Web Scraper and Sentiment Analyzer
# Authored by Chris Cotton, 07/17/2017
#
# chris.j.cotton@me.com
#
#
# ## Purpose:
#
# This notebook leverages the Goose and Textblob modules for Python which enable the scraping, parsing, and analyzing of sentiment and subjectivity of natural language data on the internet.  Goose scrapes and cleans raw web data; Textblob leverages the NLTK module for Python to perform sentiment and subjectivity analysis on the data.
#
# Some bubble charts are displayed for fun, just plotting sentiment vs. subjectivity of various parts of the data scraped (title, metadata, text, etc.).  The heatmaps display all of the attributes of the text analyzed (6 of them) vs. all observations (websites) in the data set.  A bottom-up, hierarchical, agglomerative clustering algorithm (Ward clustering) is applied whose objective function is to find pairs of rows with the most similar variance (smallest difference in erorr sum of squares between rows).  A taxonomy is created that can be pruned at any level to find clades of websites with similar sentiments.  The same algorithm is applied column-wise, to find attributes that are, holistically, most similar to one another *across* the websites.
#
#
# ## Inputs:
#
# The user defines a list of domains, and the program tries to scrape and analyze every domain in the list that it can.
#
#
# ## Execution:
#
# After defining your list, click the "Cell" menu, and click "Run All."

# %%
from __future__ import division
import os
import sys
import re
import numpy as np
import pandas as pd
import scipy

import nltk, re, pprint
from nltk import word_tokenize
import urllib2 as ul2
from goose import Goose
from textblob import TextBlob

import plotly.plotly as py 
from plotly.graph_objs import *
import plotly.graph_objs as go
from plotly import __version__
import plotly.offline as offline
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)

import rpy2 as r
from rpy2.robjects.packages import importr
import rpy2.robjects as ro
from rpy2.robjects import conversion
from rpy2.robjects import pandas2ri
from IPython.display import display, HTML, IFrame
# Out:
# //anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning:
#
# Matplotlib is building the font cache using fc-list. This may take a moment.
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
# %load_ext rpy2.ipython

import warnings
warnings.filterwarnings('ignore')

# %%
# %R require(ggplot2); require(tidyr); require(plotly); require(d3heatmap)
# Out:
# array([1], dtype=int32)

# %%
R = ro.r
pandas2ri.activate()
# plotly = importr("plotly")
# d3heatmap = importr("d3heatmap")
# forcats = importr("forcats")
# anomaly = importr("AnomalyDetection")

root_dir = os.getcwd()
output_dir = root_dir

# %%
g = Goose()

# %%
domain_list = ["google.com","youtube.com","facebook.com","baidu.com","wikipedia.org","yahoo.com","reddit.com","google.co.in","qq.com","amazon.com","taobao.com","twitter.com","tmall.com","google.co.jp","vk.com","live.com","sohu.com","instagram.com","sina.com.cn","jd.com","weibo.com","360.cn","google.de","google.co.uk","google.com.br","list.tmall.com","linkedin.com","google.fr","google.ru","yandex.ru","netflix.com","google.com.hk","yahoo.co.jp","google.it","ebay.com","t.co","pornhub.com","google.es","imgur.com","bing.com","twitch.tv","msn.com","onclkds.com","gmw.cn","tumblr.com","google.com.mx","google.ca","alipay.com","xvideos.com","livejasmin.com","mail.ru","ok.ru","microsoft.com","aliexpress.com","wordpress.com","hao123.com","stackoverflow.com","imdb.com","amazon.co.jp","github.com","blogspot.com","csdn.net","wikia.com","pinterest.com","apple.com","google.com.tr","popads.net","youth.cn","bongacams.com","office.com","paypal.com","google.com.tw","google.com.au","whatsapp.com","microsoftonline.com","google.pl","xhamster.com","detail.tmall.com","diply.com","google.co.id","adobe.com","nicovideo.jp","craigslist.org","amazon.de","txxx.com","amazon.in","google.com.ar","porn555.com","coccoc.com","dropbox.com","booking.com","thepiratebay.org","google.com.pk","googleusercontent.com","google.co.th","pixnet.net","china.com","google.com.eg","soso.com","bbc.co.uk","tianya.cn","google.com.sa","amazon.co.uk","savefrom.net","fc2.com","bbc.com","rakuten.co.jp","uptodown.com","so.com","soundcloud.com","google.com.ua","mozilla.org","xnxx.com","cnn.com","amazonaws.com","quora.com","ask.com","google.nl","ettoday.net","nytimes.com","naver.com","adf.ly","dailymotion.com","clicksgear.com","google.co.za","steamcommunity.com","onlinesbi.com","google.co.ve","espn.com","google.co.kr","salesforce.com","chase.com","fbcdn.net","blogger.com","stackexchange.com","ebay.de","vice.com","vimeo.com","theguardian.com","chaturbate.com","steampowered.com","blastingnews.com","ebay.co.uk","mediafire.com","tribunnews.com","indeed.com","buzzfeed.com","openload.co","google.gr","avito.ru"]

# %%
url_list = ["http://www." + i for i in domain_list]

# %%
def parse_and_analyze(url):
    domain = url.replace("http://www.","")
    parsed = g.extract(url)

    title = parsed.title
    meta = parsed.meta_description
    text = parsed.cleaned_text
    overall = title + " " + meta + " " + text

    title_blob = TextBlob(title)
    meta_blob = TextBlob(meta)
    text_blob = TextBlob(text)
    overall_blob = TextBlob(overall)

    title_sentiment = title_blob.sentiment.polarity
    meta_sentiment = meta_blob.sentiment.polarity
    text_sentiment = text_blob.sentiment.polarity
    overall_sentiment = overall_blob.sentiment.polarity

    title_subjectivity = title_blob.sentiment.subjectivity
    meta_subjectivity = meta_blob.sentiment.subjectivity
    text_subjectivity = text_blob.sentiment.subjectivity
    overall_subjectivity = overall_blob.sentiment.subjectivity

    results_list = [
    domain, title, meta, text,
    title_sentiment, meta_sentiment, text_sentiment, overall_sentiment,
    title_subjectivity, meta_subjectivity, text_subjectivity, overall_subjectivity
    ]

    return results_list



def merge(url_list):
    results_list = []
    successful = []
    failed = []

    i = 0
    s = 0
    f = 0

    for url in url_list:
        try:
            results = parse_and_analyze(url)
            results_list.append(results)
            successful.append(url)
            i += 1
            s += 1
            print url + " successful!"
            print "{} urls processed so far; {} successful; {} failed.".format(i, s, f)
        except:
            failed.append(url)
            i += 1
            f += 1
            print url + " failed..."
            print "{} urls processed so far; {} successful; {} failed.".format(i, s, f)

    df = pd.DataFrame(results_list)

    return df, successful, failed

# %%
df, successful, failed = merge(url_list)
# Out:
# http://www.google.com successful!
# 1 urls processed so far; 1 successful; 0 failed.
# http://www.youtube.com successful!
# 2 urls processed so far; 2 successful; 0 failed.
# http://www.facebook.com successful!
# 3 urls processed so far; 3 successful; 0 failed.
# http://www.baidu.com successful!
# 4 urls processed so far; 4 successful; 0 failed.
# http://www.wikipedia.org successful!
# 5 urls processed so far; 5 successful; 0 failed.
# http://www.yahoo.com failed...
# 6 urls processed so far; 5 successful; 1 failed.
# http://www.reddit.com successful!
# 7 urls processed so far; 6 successful; 1 failed.
# http://www.google.co.in successful!
# 8 urls processed so far; 7 successful; 1 failed.
# http://www.qq.com successful!
# 9 urls processed so far; 8 successful; 1 failed.
# http://www.amazon.com successful!
# 10 urls processed so far; 9 successful; 1 failed.
# http://www.taobao.com successful!
# 11 urls processed so far; 10 successful; 1 failed.
# http://www.twitter.com successful!
# 12 urls processed so far; 11 successful; 1 failed.
# http://www.tmall.com successful!
# 13 urls processed so far; 12 successful; 1 failed.
# http://www.google.co.jp successful!
# 14 urls processed so far; 13 successful; 1 failed.
# http://www.vk.com successful!
# 15 urls processed so far; 14 successful; 1 failed.
# http://www.live.com successful!
# 16 urls processed so far; 15 successful; 1 failed.
# http://www.sohu.com successful!
# 17 urls processed so far; 16 successful; 1 failed.
# http://www.instagram.com failed...
# 18 urls processed so far; 16 successful; 2 failed.
# http://www.sina.com.cn successful!
# 19 urls processed so far; 17 successful; 2 failed.
# http://www.jd.com successful!
# 20 urls processed so far; 18 successful; 2 failed.
# http://www.weibo.com successful!
# 21 urls processed so far; 19 successful; 2 failed.
# http://www.360.cn failed...
# 22 urls processed so far; 19 successful; 3 failed.
# http://www.google.de successful!
# 23 urls processed so far; 20 successful; 3 failed.
# http://www.google.co.uk successful!
# 24 urls processed so far; 21 successful; 3 failed.
# http://www.google.com.br successful!
# 25 urls processed so far; 22 successful; 3 failed.
# http://www.list.tmall.com successful!
# 26 urls processed so far; 23 successful; 3 failed.
# http://www.linkedin.com successful!
# 27 urls processed so far; 24 successful; 3 failed.
# http://www.google.fr successful!
# 28 urls processed so far; 25 successful; 3 failed.
# http://www.google.ru successful!
# 29 urls processed so far; 26 successful; 3 failed.
# http://www.yandex.ru failed...
# 30 urls processed so far; 26 successful; 4 failed.
# http://www.netflix.com successful!
# 31 urls processed so far; 27 successful; 4 failed.
# http://www.google.com.hk successful!
# 32 urls processed so far; 28 successful; 4 failed.
# http://www.yahoo.co.jp successful!
# 33 urls processed so far; 29 successful; 4 failed.
# http://www.google.it successful!
# 34 urls processed so far; 30 successful; 4 failed.
# http://www.ebay.com successful!
# 35 urls processed so far; 31 successful; 4 failed.
# http://www.t.co successful!
# 36 urls processed so far; 32 successful; 4 failed.
# http://www.pornhub.com successful!
# 37 urls processed so far; 33 successful; 4 failed.
# http://www.google.es successful!
# 38 urls processed so far; 34 successful; 4 failed.
# http://www.imgur.com failed...
# 39 urls processed so far; 34 successful; 5 failed.
# http://www.bing.com successful!
# 40 urls processed so far; 35 successful; 5 failed.
# http://www.twitch.tv failed...
# 41 urls processed so far; 35 successful; 6 failed.
# http://www.msn.com failed...
# 42 urls processed so far; 35 successful; 7 failed.
# http://www.onclkds.com successful!
# 43 urls processed so far; 36 successful; 7 failed.
# http://www.gmw.cn successful!
# 44 urls processed so far; 37 successful; 7 failed.
# http://www.tumblr.com successful!
# 45 urls processed so far; 38 successful; 7 failed.
# http://www.google.com.mx successful!
# 46 urls processed so far; 39 successful; 7 failed.
# http://www.google.ca successful!
# 47 urls processed so far; 40 successful; 7 failed.
# http://www.alipay.com successful!
# 48 urls processed so far; 41 successful; 7 failed.
# http://www.xvideos.com successful!
# 49 urls processed so far; 42 successful; 7 failed.
# http://www.livejasmin.com successful!
# 50 urls processed so far; 43 successful; 7 failed.
# http://www.mail.ru successful!
# 51 urls processed so far; 44 successful; 7 failed.
# http://www.ok.ru failed...
# 52 urls processed so far; 44 successful; 8 failed.
# http://www.microsoft.com successful!
# 53 urls processed so far; 45 successful; 8 failed.
# http://www.aliexpress.com successful!
# 54 urls processed so far; 46 successful; 8 failed.
# http://www.wordpress.com successful!
# 55 urls processed so far; 47 successful; 8 failed.
# http://www.hao123.com successful!
# 56 urls processed so far; 48 successful; 8 failed.
# http://www.stackoverflow.com successful!
# 57 urls processed so far; 49 successful; 8 failed.
# http://www.imdb.com successful!
# 58 urls processed so far; 50 successful; 8 failed.
# http://www.amazon.co.jp successful!
# 59 urls processed so far; 51 successful; 8 failed.
# http://www.github.com successful!
# 60 urls processed so far; 52 successful; 8 failed.
# http://www.blogspot.com successful!
# 61 urls processed so far; 53 successful; 8 failed.
# http://www.csdn.net successful!
# 62 urls processed so far; 54 successful; 8 failed.
# http://www.wikia.com failed...
# 63 urls processed so far; 54 successful; 9 failed.
# http://www.pinterest.com failed...
# 64 urls processed so far; 54 successful; 10 failed.
# http://www.apple.com failed...
# 65 urls processed so far; 54 successful; 11 failed.
# http://www.google.com.tr successful!
# 66 urls processed so far; 55 successful; 11 failed.
# http://www.popads.net successful!
# 67 urls processed so far; 56 successful; 11 failed.
# http://www.youth.cn successful!
# 68 urls processed so far; 57 successful; 11 failed.
# http://www.bongacams.com successful!
# 69 urls processed so far; 58 successful; 11 failed.
# http://www.office.com successful!
# 70 urls processed so far; 59 successful; 11 failed.
# http://www.paypal.com successful!
# 71 urls processed so far; 60 successful; 11 failed.
# http://www.google.com.tw successful!
# 72 urls processed so far; 61 successful; 11 failed.
# http://www.google.com.au successful!
# 73 urls processed so far; 62 successful; 11 failed.
# http://www.whatsapp.com successful!
# 74 urls processed so far; 63 successful; 11 failed.
# http://www.microsoftonline.com successful!
# 75 urls processed so far; 64 successful; 11 failed.
# http://www.google.pl successful!
# 76 urls processed so far; 65 successful; 11 failed.
# http://www.xhamster.com successful!
# 77 urls processed so far; 66 successful; 11 failed.
# http://www.detail.tmall.com successful!
# 78 urls processed so far; 67 successful; 11 failed.
# http://www.diply.com failed...
# 79 urls processed so far; 67 successful; 12 failed.
# http://www.google.co.id successful!
# 80 urls processed so far; 68 successful; 12 failed.
# http://www.adobe.com successful!
# 81 urls processed so far; 69 successful; 12 failed.
# http://www.nicovideo.jp failed...
# 82 urls processed so far; 69 successful; 13 failed.
# http://www.craigslist.org successful!
# 83 urls processed so far; 70 successful; 13 failed.
# http://www.amazon.de successful!
# 84 urls processed so far; 71 successful; 13 failed.
# http://www.txxx.com successful!
# 85 urls processed so far; 72 successful; 13 failed.
# http://www.amazon.in successful!
# 86 urls processed so far; 73 successful; 13 failed.
# http://www.google.com.ar successful!
# 87 urls processed so far; 74 successful; 13 failed.
# http://www.porn555.com successful!
# 88 urls processed so far; 75 successful; 13 failed.
# http://www.coccoc.com successful!
# 89 urls processed so far; 76 successful; 13 failed.
# http://www.dropbox.com successful!
# 90 urls processed so far; 77 successful; 13 failed.
# http://www.booking.com successful!
# 91 urls processed so far; 78 successful; 13 failed.
# http://www.thepiratebay.org successful!
# 92 urls processed so far; 79 successful; 13 failed.
# http://www.google.com.pk successful!
# 93 urls processed so far; 80 successful; 13 failed.
# http://www.googleusercontent.com successful!
# 94 urls processed so far; 81 successful; 13 failed.
# http://www.google.co.th successful!
# 95 urls processed so far; 82 successful; 13 failed.
# http://www.pixnet.net successful!
# 96 urls processed so far; 83 successful; 13 failed.
# http://www.china.com failed...
# 97 urls processed so far; 83 successful; 14 failed.
# http://www.google.com.eg successful!
# 98 urls processed so far; 84 successful; 14 failed.
# http://www.soso.com successful!
# 99 urls processed so far; 85 successful; 14 failed.
# http://www.bbc.co.uk successful!
# 100 urls processed so far; 86 successful; 14 failed.
# http://www.tianya.cn successful!
# 101 urls processed so far; 87 successful; 14 failed.
# http://www.google.com.sa successful!
# 102 urls processed so far; 88 successful; 14 failed.
# http://www.amazon.co.uk successful!
# 103 urls processed so far; 89 successful; 14 failed.
# http://www.savefrom.net successful!
# 104 urls processed so far; 90 successful; 14 failed.
# http://www.fc2.com successful!
# 105 urls processed so far; 91 successful; 14 failed.
# http://www.bbc.com successful!
# 106 urls processed so far; 92 successful; 14 failed.
# http://www.rakuten.co.jp successful!
# 107 urls processed so far; 93 successful; 14 failed.
# http://www.uptodown.com successful!
# 108 urls processed so far; 94 successful; 14 failed.
# http://www.so.com successful!
# 109 urls processed so far; 95 successful; 14 failed.
# http://www.soundcloud.com successful!
# 110 urls processed so far; 96 successful; 14 failed.
# http://www.google.com.ua successful!
# 111 urls processed so far; 97 successful; 14 failed.
# http://www.mozilla.org successful!
# 112 urls processed so far; 98 successful; 14 failed.
# http://www.xnxx.com successful!
# 113 urls processed so far; 99 successful; 14 failed.
# http://www.cnn.com successful!
# 114 urls processed so far; 100 successful; 14 failed.
# http://www.amazonaws.com successful!
# 115 urls processed so far; 101 successful; 14 failed.
# http://www.quora.com successful!
# 116 urls processed so far; 102 successful; 14 failed.
# http://www.ask.com successful!
# 117 urls processed so far; 103 successful; 14 failed.
# http://www.google.nl successful!
# 118 urls processed so far; 104 successful; 14 failed.
# http://www.ettoday.net successful!
# 119 urls processed so far; 105 successful; 14 failed.
# http://www.nytimes.com successful!
# 120 urls processed so far; 106 successful; 14 failed.
# http://www.naver.com successful!
# 121 urls processed so far; 107 successful; 14 failed.
# http://www.adf.ly successful!
# 122 urls processed so far; 108 successful; 14 failed.
# http://www.dailymotion.com successful!
# 123 urls processed so far; 109 successful; 14 failed.
# http://www.clicksgear.com failed...
# 124 urls processed so far; 109 successful; 15 failed.
# http://www.google.co.za successful!
# 125 urls processed so far; 110 successful; 15 failed.
# http://www.steamcommunity.com successful!
# 126 urls processed so far; 111 successful; 15 failed.
# http://www.onlinesbi.com successful!
# 127 urls processed so far; 112 successful; 15 failed.
# http://www.google.co.ve successful!
# 128 urls processed so far; 113 successful; 15 failed.
# http://www.espn.com successful!
# 129 urls processed so far; 114 successful; 15 failed.
# http://www.google.co.kr successful!
# 130 urls processed so far; 115 successful; 15 failed.
# http://www.salesforce.com successful!
# 131 urls processed so far; 116 successful; 15 failed.
# http://www.chase.com successful!
# 132 urls processed so far; 117 successful; 15 failed.
# http://www.fbcdn.net successful!
# 133 urls processed so far; 118 successful; 15 failed.
# http://www.blogger.com successful!
# 134 urls processed so far; 119 successful; 15 failed.
# http://www.stackexchange.com successful!
# 135 urls processed so far; 120 successful; 15 failed.
# http://www.ebay.de successful!
# 136 urls processed so far; 121 successful; 15 failed.
# http://www.vice.com successful!
# 137 urls processed so far; 122 successful; 15 failed.
# http://www.vimeo.com successful!
# 138 urls processed so far; 123 successful; 15 failed.
# http://www.theguardian.com successful!
# 139 urls processed so far; 124 successful; 15 failed.
# http://www.chaturbate.com successful!
# 140 urls processed so far; 125 successful; 15 failed.
# http://www.steampowered.com successful!
# 141 urls processed so far; 126 successful; 15 failed.
# http://www.blastingnews.com successful!
# 142 urls processed so far; 127 successful; 15 failed.
# http://www.ebay.co.uk successful!
# 143 urls processed so far; 128 successful; 15 failed.
# http://www.mediafire.com failed...
# 144 urls processed so far; 128 successful; 16 failed.
# http://www.tribunnews.com successful!
# 145 urls processed so far; 129 successful; 16 failed.
# http://www.indeed.com successful!
# 146 urls processed so far; 130 successful; 16 failed.
# http://www.buzzfeed.com failed...
# 147 urls processed so far; 130 successful; 17 failed.
# http://www.openload.co successful!
# 148 urls processed so far; 131 successful; 17 failed.
# http://www.google.gr successful!
# 149 urls processed so far; 132 successful; 17 failed.
# http://www.avito.ru successful!
# 150 urls processed so far; 133 successful; 17 failed.

# %%
df.columns = [
"Domain", "Title", "Meta", "Text",
"Title Sentiment", "Meta Sentiment", "Text Sentiment", "Overall Sentiment",
"Title Subjectivity", "Meta Subjectivity", "Text Subjectivity", "Overall Subjectivity",
]

# %%
df.to_csv("/Users/chrcotto/cloudzero_scrapy/cloudzero_results.txt", sep = "\t", encoding = "utf-8")

# %%
df
# Out:
#                  Domain                                              Title  \
# 0            google.com                                             Google
# 1           youtube.com                                            YouTube
# 2          facebook.com                                  Log In or Sign Up
# 3             baidu.com                                          百度一下，你就知道
# 4         wikipedia.org                                          Wikipedia
# 5            reddit.com             reddit: the front page of the internet
# 6          google.co.in                                             Google
# 7                qq.com                                               腾讯首页
# 8            amazon.com  Amazon.com: Online Shopping for Electronics, A...
# 9            taobao.com                                                淘宝网
# 10          twitter.com                    Twitter. It's what's happening.
# 11            tmall.com                               天猫tmall.com--理想生活上天猫
# 12         google.co.jp                                             Google
# 13               vk.com                                  VK mobile version
# 14             live.com                                            Sign In
# 15             sohu.com                                                 搜狐
# 16          sina.com.cn                                               新浪首页
# 17               jd.com                    京东(JD.COM)-正品低价、品质保障、配送及时、轻松购物！
# 18            weibo.com                                             北美微博广场
# 19            google.de                                             Google
# 20         google.co.uk                                             Google
# 21        google.com.br                                             Google
# 22       list.tmall.com
# 23         linkedin.com                        LinkedIn: Log In or Sign Up
# 24            google.fr                                             Google
# 25            google.ru                                             Google
# 26          netflix.com  Netflix - Watch TV Shows Online, Watch Movies ...
# 27        google.com.hk                                             Google
# 28          yahoo.co.jp                                       Yahoo! JAPAN
# 29            google.it                                             Google
# ..                  ...                                                ...
# 103           google.nl                                             Google
# 104         ettoday.net                                    Today is my day
# 105         nytimes.com             Breaking News, World News & Multimedia
# 106           naver.com                                                네이버
# 19            0.000000           0.000000              0.000000
# 20            0.000000           0.000000              0.000000
# 21            0.000000           0.000000              0.000000
# 22            0.000000           0.000000              0.000000
# 23            0.100000           0.000000              0.100000
# 24            0.000000           0.000000              0.000000
# 25            0.000000           0.000000              0.000000
# 26            0.575714           0.441905              0.508810
# 27            0.000000           0.000000              0.000000
# 28            0.000000           0.000000              0.000000
# 29            0.000000           0.000000              0.000000
# ..                 ...                ...                   ...
# 103           0.000000           0.000000              0.000000
# 104           0.000000           0.000000              0.000000
# 105           0.418182           0.000000              0.418182
# 106           0.000000           0.000000              0.000000
# 107           0.000000           0.000000              0.000000
# 108           0.600000           0.000000              0.600000
# 109           0.000000           0.000000              0.000000
# 110           0.000000           0.700000              0.700000
# 111           0.000000           0.160000              0.160000
# 112           0.000000           0.000000              0.000000
# 113           0.500000           0.000000              0.500000
# 114           0.000000           0.000000              0.000000
# 115           0.383333           0.775000              0.462500
# 116           0.000000           0.550000              0.275000
# 117           0.375000           0.000000              0.375000
# 118           0.925000           0.537500              0.790278
# 119           0.000000           0.625794              0.657823
# 120           0.000000           0.000000              0.000000
# 121           0.750000           0.000000              0.750000
# 122           0.800000           0.000000              0.800000
# 123           0.900000           0.566667              0.650000
# 124           0.000000           0.000000              0.000000
# 125           0.000000           0.484848              0.588636
# 126           0.231250           0.445625              0.345385
# 127           0.000000           0.566667              0.408333
# 128           0.000000           0.000000              0.000000
# 129           0.000000           0.000000              0.000000
# 130           0.000000           0.000000              0.800000
# 131           0.000000           0.000000              0.000000
# 132           0.000000           0.000000              0.000000
#
# [133 rows x 12 columns]

# %%
df.describe()
# Out:
#        Title Sentiment  Meta Sentiment  Text Sentiment  Overall Sentiment  \
# count       133.000000      133.000000      133.000000         133.000000
# mean          0.068307        0.115469        0.079280           0.139452
# std           0.169876        0.202842        0.210016           0.203553
# min           0.000000       -0.125000       -0.400000          -0.125000
# 25%           0.000000        0.000000        0.000000           0.000000
# 50%           0.000000        0.000000        0.000000           0.000000
# 75%           0.000000        0.200000        0.000000           0.300000
# max           0.800000        0.800000        1.000000           0.800000
#
#        Title Subjectivity  Meta Subjectivity  Text Subjectivity  \
# count          133.000000         133.000000         133.000000
# mean             0.097870           0.180445           0.127392
# std              0.251001           0.293305           0.234539
# min              0.000000           0.000000           0.000000
# 25%              0.000000           0.000000           0.000000
# 50%              0.000000           0.000000           0.000000
# 75%              0.000000           0.375000           0.160000
# max              1.000000           1.000000           1.000000
#
#        Overall Subjectivity
# count            133.000000
# mean               0.225333
# std                0.287854
# min                0.000000
# 25%                0.000000
# 50%                0.000000
# 75%                0.500000
# max                0.900000

# %%
df[df.sum(axis = 1) > 0].describe()
# Out:
#        Title Sentiment  Meta Sentiment  Text Sentiment  Overall Sentiment  \
# count        57.000000       57.000000       57.000000          57.000000
# mean          0.159383        0.269427        0.184986           0.325387
# std           0.230753        0.234015        0.289936           0.189959
# min           0.000000       -0.125000       -0.400000          -0.125000
# 25%           0.000000        0.000000        0.000000           0.243750
# 50%           0.000000        0.283333        0.033333           0.333333
# 75%           0.400000        0.500000        0.312500           0.452778
# max           0.800000        0.800000        1.000000           0.800000
#
#        Title Subjectivity  Meta Subjectivity  Text Subjectivity  \
# count           57.000000          57.000000          57.000000
# mean             0.228363           0.421038           0.297249
# std              0.343761           0.315708           0.279772
# min              0.000000           0.000000           0.000000
# 25%              0.000000           0.100000           0.000000
# 50%              0.000000           0.455357           0.300000
# 75%              0.500000           0.616667           0.537500
# max              1.000000           1.000000           1.000000
#
#        Overall Subjectivity
# count             57.000000
# mean               0.525777
# std                0.185811
# min                0.100000
# 25%                0.418182
# 50%                0.500000
# 75%                0.650000
# max                0.900000

# %%
hover_text = []

for index, row in df.iterrows():
    hover_text.append(
        ('Domain: {domain}<br>'+
        'Title Sentiment: {title}<br>'+
        'Text Sentiment: {text}<br>').format(
                                        domain = row["Domain"],
                                        title = row["Title Sentiment"],
                                        text = row["Text Sentiment"]
                                        )
                     )


df["Hover Text"] = hover_text


trace0 = go.Scatter(
    x = df["Title Sentiment"],
    y = df["Text Sentiment"],
    text = df["Hover Text"],
    mode = "markers",
    marker = dict(
        size=[40] * len(df),
    )
)


layout = go.Layout(
    title = "Text vs. Title Sentiment for Top Alexa Sites",
    xaxis = dict(
        title = "Title Sentiment Score",
        gridcolor = "rgb(255, 255, 255)",
        zerolinewidth = 1,
        ticklen = 5,
        gridwidth = 2,
    ),
    yaxis=dict(
        title = "Text Sentiment Score",
        gridcolor = "rgb(255, 255, 255)",
        zerolinewidth = 1,
        ticklen = 5,
        gridwidth = 2,
    ),
    paper_bgcolor='rgb(243, 243, 243)',
    plot_bgcolor='rgb(243, 243, 243)',
)


data = [trace0]

fig = go.Figure(data = data, layout = layout)
py.iplot(fig, filename = "bubblechart-size")
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~Durandal2794/12.embed" height="525px" width="100%"></iframe>

# %%
hover_text = []

for index, row in df.iterrows():
    hover_text.append(
        ('Domain: {domain}<br>'+
        'Subjectivity: {subjectivity}<br>'+
        'Sentiment: {sentiment}<br>').format(
                                        domain = row["Domain"],
                                        subjectivity = row["Text Subjectivity"],
                                        sentiment = row["Text Sentiment"]
                                        )
                     )


df["Hover Text2"] = hover_text


trace0 = go.Scatter(
    x = df["Text Subjectivity"],
    y = df["Text Sentiment"],
    text = df["Hover Text2"],
    mode = "markers",
    marker = dict(
        size=[40] * len(df),
    )
)


layout = go.Layout(
    title = "Text Sentiment vs. Subjectivity for Top Alexa Sites",
    xaxis = dict(
        title = "Text Subjectivity Score",
        gridcolor = "rgb(255, 255, 255)",
        zerolinewidth = 1,
        ticklen = 5,
        gridwidth = 2,
    ),
    yaxis=dict(
        title = "Text Sentiment Score",
        gridcolor = "rgb(255, 255, 255)",
        zerolinewidth = 1,
        ticklen = 5,
        gridwidth = 2,
    ),
    paper_bgcolor='rgb(243, 243, 243)',
    plot_bgcolor='rgb(243, 243, 243)',
)


data = [trace0]

fig = go.Figure(data = data, layout = layout)
py.iplot(fig, filename = "bubblechart-size")
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~Durandal2794/12.embed" height="525px" width="100%"></iframe>

# %%
df_heatmap = df[["Domain","Title Sentiment","Meta Sentiment","Text Sentiment",
                "Title Subjectivity","Meta Subjectivity","Text Subjectivity"]]

df_heatmap.set_index("Domain", inplace = True)
df_heatmap = df_heatmap[df_heatmap.sum(axis = 1) > 0]
df_row_normalized = df_heatmap.div(df_heatmap.sum(axis = 1), axis = 0)
df_col_normalized = df_heatmap.div(df_heatmap.sum(axis = 0), axis = 1)

# %%
df_heatmap.head()
# Out:
#                Title Sentiment  Meta Sentiment  Text Sentiment  \
# Domain
# google.com                 0.0        0.401786        0.000000
# youtube.com                0.0        0.425000       -0.133333
# facebook.com               0.0       -0.125000        0.000000
# wikipedia.org              0.0        0.400000        0.000000
# amazon.com                 0.5        0.000000        1.000000
#
#                Title Subjectivity  Meta Subjectivity  Text Subjectivity
# Domain
# google.com                    0.0           0.455357                0.0
# youtube.com                   0.0           0.616667                0.3
# facebook.com                  0.0           0.375000                0.0
# wikipedia.org                 0.0           0.800000                0.0
# amazon.com                    0.5           0.300000                0.3

# %%
df_row_normalized.head()
# Out:
#                Title Sentiment  Meta Sentiment  Text Sentiment  \
# Domain
# google.com            0.000000        0.468750        0.000000
# youtube.com           0.000000        0.351724       -0.110345
# facebook.com          0.000000       -0.500000        0.000000
# wikipedia.org         0.000000        0.333333        0.000000
# amazon.com            0.192308        0.000000        0.384615
#
#                Title Subjectivity  Meta Subjectivity  Text Subjectivity
# Domain
# google.com               0.000000           0.531250           0.000000
# youtube.com              0.000000           0.510345           0.248276
# facebook.com             0.000000           1.500000           0.000000
# wikipedia.org            0.000000           0.666667           0.000000
# amazon.com               0.192308           0.115385           0.115385

# %%
df_col_normalized.head()
# Out:
#                Title Sentiment  Meta Sentiment  Text Sentiment  \
# Domain
# google.com            0.000000        0.026162        0.000000
# youtube.com           0.000000        0.027674       -0.012645
# facebook.com          0.000000       -0.008139        0.000000
# wikipedia.org         0.000000        0.026046        0.000000
# amazon.com            0.055037        0.000000        0.094839
#
#                Title Subjectivity  Meta Subjectivity  Text Subjectivity
# Domain
# google.com               0.000000           0.018974           0.000000
# youtube.com              0.000000           0.025695           0.017706
# facebook.com             0.000000           0.015626           0.000000
# wikipedia.org            0.000000           0.033335           0.000000
# amazon.com               0.038412           0.012500           0.017706

# %%
# %%R -i df_heatmap
# p <- d3heatmap(df_heatmap, colors = "YlGnBu", theme = "dark", height = 800, width = 800,
#           k_row = 18, k_col = 6, scale = "none", symm = TRUE,
#             hclustfun = function(x) hclust(x, method = "ward.D2"),
#                 na.rm = TRUE, xaxis_font_size = 12, yaxis_font_size = 11)
# htmlwidgets::saveWidget(as.widget(p), "/users/chrcotto/df_heatmap.html", selfcontained = T)

# %%
IFrame("df_heatmap.html", width = 900, height = 900)
# Out:
#         <iframe
#             width="900"
#             height="900"
#             src="df_heatmap.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# %%R -i df_row_normalized
# p2 <- d3heatmap(df_row_normalized, colors = "YlGnBu", theme = "dark", height = 800, width = 800,
#           k_row = 18, k_col = 6, scale = "row", symm = TRUE,
#             hclustfun = function(x) hclust(x, method = "ward.D2"),
#                 na.rm = TRUE, xaxis_font_size = 12, yaxis_font_size = 11)
# htmlwidgets::saveWidget(as.widget(p2), "/users/chrcotto/df_heatmap_row_normal.html", selfcontained = T)

# %%
IFrame("df_heatmap_row_normal.html", width = 900, height = 900)
# Out:
#         <iframe
#             width="900"
#             height="900"
#             src="df_heatmap_row_normal.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# %%R -i df_col_normalized
# p3 <- d3heatmap(df_col_normalized, colors = "YlGnBu", theme = "dark", height = 800, width = 800,
#           k_row = 18, k_col = 6, scale = "col", symm = TRUE,
#             hclustfun = function(x) hclust(x, method = "ward.D2"),
#                 na.rm = TRUE, xaxis_font_size = 12, yaxis_font_size = 11)
# htmlwidgets::saveWidget(as.widget(p3), "/users/chrcotto/df_heatmap_col_normal.html", selfcontained = T)

# %%
IFrame("df_heatmap_col_normal.html", width = 900, height = 900)
# Out:
#         <iframe
#             width="900"
#             height="900"
#             src="df_heatmap_col_normal.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
